# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
NFE = [39, 67, 99, 165, 203, 385]
NFE_sde = [40, 68, 100, 166, 204, 386]

# %%
si_sdr_euler = [-3.66, -2.97, -2.49, -2.49, -2.31, -2.09]
si_sdr_heun = [-1.2, -1.76, -1.94, -2.04, -2.18, -2.33]
si_sdr_sde = [0.02, 0.79, 2.16, 2.2, 2.02, 1.09]
si_sdr_restart = [0.14, 0.58, -0.33, -0.18, -0.39, -0.51]

# %%
plt.plot(NFE, si_sdr_euler, 'bo-')
plt.plot(NFE, si_sdr_heun, 'ro-')
plt.plot(NFE_sde, si_sdr_sde, 'go-')
plt.plot(NFE, si_sdr_restart, 'yo-')
